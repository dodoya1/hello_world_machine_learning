# %% [markdown]
# <a href="https://colab.research.google.com/github/dodoya1/hello_world_machine_learning/blob/main/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E3%81%AE%E3%83%8F%E3%83%AD%E3%83%BC%E3%83%AF%E3%83%BC%E3%83%AB%E3%83%89%E3%81%AB%E6%8C%91%E6%88%A6%E3%81%97%E3%81%A6%E3%81%BF%E3%82%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [機械学習のハローワールドに挑戦してみる](https://developers.google.com/codelabs/tensorflow-1-helloworld#0)
#
# 次の数字セットについて考えてみましょう。お客様との関係を確認することはできますか？
# ![スクリーンショット 2023-01-02 13.50.04.png](data:image/png;base64,...)
# これらの指標を見ると、左から右に読むと X の値が 1 増加し、Y の値が 3 増加していることがわかります。Y は 3 のプラスマイナスに等しいと考えるでしょう。すると、おそらく X の 0 を見て、Y が 1 になり、Y=3X+1 の関係が得られます。
#
# (参考文献)
#
# [機械学習を用いたコンピュータービジョンの基本（機械学習ゼロからヒーローへ　第一部）](https://youtu.be/8RfPv_rqOfY)
#
# [機械学習のハローワールドに挑戦してみる](https://developers.google.com/codelabs/tensorflow-1-helloworld#0)

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

model.fit(xs, ys, epochs=500)

print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 2s 2s/step - loss: 84.9538
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 66.8415
# Epoch 3/500
# 1/1 [==============================] - 0s 6ms/step - loss: 52.5916
# Epoch 4/500
# 1/1 [==============================] - 0s 12ms/step - loss: 41.3803
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 32.5598
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 25.6201
# Epoch 7/500
# 1/1 [==============================] - 0s 10ms/step - loss: 20.1602
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 15.8646
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 12.4849
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.8259
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.7339
# Epoch 12/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.0878
# ...
